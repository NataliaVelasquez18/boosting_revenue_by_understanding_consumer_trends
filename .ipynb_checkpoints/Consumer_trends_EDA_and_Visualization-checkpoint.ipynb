# %% [markdown]
# ### Import Libraries

# %%
# Libraries to help with reading and manipulating data
import numpy as np
import pandas as pd

# %%
# Libraries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %%
# Removes the limit for the number of displayed columns
pd.set_option("display.max_columns", None)
# Sets the limit for the number of displayed rows
pd.set_option("display.max_rows", 200)

# %%
# To supress numerical display in scientific notations - only two decimasl for float datatypes
pd.set_option("display.float_format", lambda x: "%.2f" % x)

# %%
# Avoid displaying warnings
import warnings

# %%
# this will help in making the Python code more structured automatically (good coding practice)
# %load_ext nb_black
# Out:
# The nb_black extension is already loaded. To reload it, use:
#   %reload_ext nb_black

# %%
# loading the dataset
df = pd.read_csv("shopping_trends_updated.csv")

# %%
# checking shape of the data
print(f"There are {df.shape[0]} rows and {df.shape[1]} columns in the dataset")
# Out:
# There are 3900 rows and 18 columns in the dataset

# %%
df.head(2)
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
#
#    Location Size   Color  Season  Review Rating Subscription Status  \
# 0  Kentucky    L    Gray  Winter           3.10                 Yes
# 1     Maine    L  Maroon  Winter           3.10                 Yes
#
#   Shipping Type Discount Applied Promo Code Used  Previous Purchases  \
# 0       Express              Yes             Yes                  14
# 1       Express              Yes             Yes                   2
#
#   Payment Method Frequency of Purchases
# 0          Venmo            Fortnightly
# 1           Cash            Fortnightly

# %%
# to view last 5 rows of the dataset
df.tail(200)
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 3700         3701   28  Female        Handbag  Accessories
# 3701         3702   46  Female        Sandals     Footwear
# 3702         3703   58  Female          Shoes     Footwear
# 3703         3704   30  Female        Sandals     Footwear
# 3704         3705   68  Female     Sunglasses  Accessories
# 3705         3706   28  Female          Skirt     Clothing
# 3706         3707   26  Female        Sandals     Footwear
# 3707         3708   35  Female         Gloves  Accessories
# 3708         3709   40  Female         Hoodie     Clothing
# 3709         3710   31  Female          Socks     Clothing
# 3710         3711   60  Female        Jewelry  Accessories
# 3711         3712   69  Female            Hat  Accessories
# 3712         3713   51  Female         Blouse     Clothing
# 3713         3714   49  Female          Shoes     Footwear
# 3714         3715   18  Female            Hat  Accessories
# 3715         3716   63  Female     Sunglasses  Accessories
# 3716         3717   57  Female          Shirt     Clothing
# 3717         3718   45  Female        T-shirt     Clothing
# 3718         3719   36  Female          Pants     Clothing
# 3719         3720   20  Female          Pants     Clothing
# 3720         3721   21  Female            Hat  Accessories
# 3721         3722   62  Female           Coat    Outerwear
# 3722         3723   23  Female         Jacket    Outerwear
# 3723         3724   26  Female        Sandals     Footwear
# 3724         3725   30  Female         Gloves  Accessories
# 3725         3726   18  Female          Dress     Clothing
# 3726         3727   47  Female           Belt  Accessories
# 3727         3728   41  Female          Socks     Clothing
# 3728         3729   62  Female         Jacket    Outerwear
# 3729         3730   28  Female          Boots     Footwear
# 3730         3731   46  Female          Shirt     Clothing
# 3731         3732   54  Female            Hat  Accessories
# 3732         3733   36  Female          Shoes     Footwear
# 3733         3734   25  Female          Socks     Clothing
# 3734         3735   38  Female         Hoodie     Clothing
# 3735         3736   38  Female        Sandals     Footwear
# 3736         3737   42  Female          Jeans     Clothing
# 3737         3738   19  Female        Jewelry  Accessories
# 3738         3739   34  Female         Shorts     Clothing
# 3739         3740   38  Female     Sunglasses  Accessories
# 3740         3741   42  Female          Pants     Clothing
# 3741         3742   58  Female          Shirt     Clothing
# 3742         3743   56  Female          Shirt     Clothing
# 3743         3744   62  Female          Pants     Clothing
# 3744         3745   24  Female         Hoodie     Clothing
# 3745         3746   60  Female          Socks     Clothing
# 3746         3747   53  Female           Coat    Outerwear
# 3747         3748   26  Female        Sweater     Clothing
# 3748         3749   34  Female       Backpack  Accessories
# 3882         3883   35  Female          Pants     Clothing
# 3883         3884   34  Female            Hat  Accessories
# 3884         3885   47  Female        Sandals     Footwear
# 3885         3886   49  Female          Socks     Clothing
# 3886         3887   37  Female        Jewelry  Accessories
# 3887         3888   40  Female          Shirt     Clothing
# 3888         3889   45  Female       Sneakers     Footwear
# 3889         3890   57  Female          Dress     Clothing
# 3890         3891   35  Female          Shirt     Clothing
# 3891         3892   36  Female          Dress     Clothing
# 3892         3893   35  Female        Jewelry  Accessories
# 3893         3894   21  Female            Hat  Accessories
# 3894         3895   66  Female          Skirt     Clothing
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)        Location Size      Color  Season  \
# 3700                     84    North Dakota   XL   Charcoal  Summer
# 3701                     66      New Mexico    M   Charcoal  Spring
# 3702                     65  South Carolina    M     Indigo  Spring
# 3703                     83        Michigan    S       Teal    Fall
# 3704                     61        Missouri    L      Black  Winter
# 3705                     65        Colorado    L       Teal  Summer
# 3706                     55          Kansas    M      Green  Spring
# 3707                     79        Illinois    M       Gold    Fall
# 3708                     96  South Carolina    M        Red    Fall
# 3709                     43            Utah    M     Silver    Fall
# 3710                     40          Hawaii    M     Yellow  Summer
# 3711                     62           Texas   XL      Peach    Fall
# 3712                     72          Oregon    M  Turquoise  Spring
# 3713                     87         Arizona    M      Peach  Spring
# 3714                     31        New York    S      Peach  Winter
# 3715                     34        Nebraska    S     Orange    Fall
# 3716                     53         Vermont    M   Charcoal    Fall
# 3717                     85        Maryland   XL      White  Summer
# 3718                     50       Tennessee    L  Turquoise    Fall
# 3719                     91    Pennsylvania    M        Red  Summer
# 3720                     56  South Carolina    M      Peach    Fall
# 3721                     60     Connecticut    L       Pink    Fall
# 3722                     34        Kentucky   XL     Yellow    Fall
# 3723                     30    Rhode Island    M      Beige  Spring
# 3724                     71        Colorado    L      Green  Winter
# 3725                    100        Oklahoma    S  Turquoise  Winter
# 3726                     85           Idaho   XL     Orange    Fall
# 3727                     83           Maine    M       Gold  Summer
# 3728                     31         Vermont    L        Red  Winter
# 3729                     82    Rhode Island    M       Teal  Spring
# 3730                     79         Florida    M       Teal  Summer
# 3731                     62   West Virginia    M   Lavender  Spring
# 3732                     92         Indiana    L       Pink  Spring
# 3733                     58        Illinois    M     Maroon    Fall
# 3734                     88      California    M      Beige  Spring
# 3735                     44   Massachusetts    L     Orange  Spring
# 3736                     56           Idaho    M        Red  Spring
# 3737                     23        Kentucky    S     Maroon  Winter
# 3738                     45        Delaware    M      Brown  Spring
# 3739                     31           Idaho    M      Olive    Fall
# 3740                     96        Virginia    M     Silver  Summer
# 3741                     96         Arizona    M     Purple  Spring
# 3742                     80        Maryland    M       Gray    Fall
# 3743                     28           Idaho    L       Cyan    Fall
# 3744                     51      New Jersey    M       Gray  Summer
# 3745                     41      Washington    L       Gold  Spring
# 3746                     99           Idaho   XL       Cyan  Summer
# 3747                     53    Rhode Island    L      Olive  Spring
# 3748                     25        Delaware    M     Violet    Fall
# 3749                     95          Alaska    L     Yellow  Winter
# 3750                     88         Arizona    M       Gold    Fall
# 3751                     97         Alabama    S     Silver    Fall
# 3752                     81      Washington    L       Pink  Winter
# 3753                     26       Louisiana    S  Turquoise  Winter
# 3754                     41        Nebraska    M  Turquoise  Summer
# 3755                     93    Pennsylvania    M      Peach    Fall
# 3756                     69  South Carolina    L       Teal  Spring
# 3757                     44      California    L        Red    Fall
# 3758                     54         Indiana    S      Black  Spring
# 3759                     61        Missouri    M       Pink  Spring
# 3760                     80     Connecticut    M      Peach    Fall
# 3761                     30          Nevada    M      Green  Summer
# 3762                     94        New York    L      Green    Fall
# 3763                     24        Oklahoma   XL        Red  Winter
# 3764                     21    South Dakota    M     Maroon    Fall
# 3765                     52        Missouri    M      Green  Summer
# 3766                     59           Texas    M      Black    Fall
# 3767                     51        New York   XL      Black  Summer
# 3768                     35         Vermont    M     Yellow  Winter
# 3769                     87         Arizona    L      Green  Summer
# 3770                     42         Montana    L      Black  Summer
# 3771                     86        Oklahoma    M        Red  Winter
# 3772                     26   New Hampshire    L     Yellow    Fall
# 3773                     60       Wisconsin    M     Violet  Summer
# 3774                     83          Alaska    S       Cyan  Winter
# 3775                     63    South Dakota    S       Pink  Spring
# 3776                     25          Alaska    L      Olive  Spring
# 3777                     65            Utah    M     Maroon    Fall
# 3778                     60    South Dakota    M       Cyan    Fall
# 3779                     75      California   XL   Lavender  Spring
# 3780                     57     Mississippi    L     Yellow    Fall
# 3781                     99       Tennessee    M       Pink  Winter
# 3782                     45         Alabama    L     Orange  Spring
# 3783                     66           Maine   XL     Orange  Summer
# 3784                     53        Virginia    M     Violet  Winter
# 3785                     94   New Hampshire    L   Lavender  Winter
# 3786                     47       Tennessee    L     Yellow    Fall
# 3787                     80        New York    M       Pink    Fall
# 3788                     65          Kansas   XL       Teal  Spring
# 3789                     75    North Dakota    M    Magenta  Summer
# 3790                     45          Alaska   XL      Beige  Summer
# 3791                     51           Texas    M       Gray  Spring
# 3792                     58   Massachusetts    S  Turquoise  Summer
# 3793                     20        Delaware    M       Pink    Fall
# 3794                     82    South Dakota    M     Violet  Summer
# 3795                     92        Arkansas    M   Charcoal  Spring
# 3796                     81            Utah    M   Lavender    Fall
# 3797                     44      California    M       Gray  Summer
# 3798                     72    Rhode Island    S      Brown  Winter
# 3799                     26        Oklahoma    L     Violet  Winter
# 3800                     26         Vermont    M  Turquoise    Fall
# 3801                     84        Kentucky    M      Peach  Spring
# 3802                     72        Illinois    S  Turquoise  Spring
# 3803                     55     Connecticut    M     Violet  Spring
# 3804                     77         Florida    M      Olive    Fall
# 3805                     57      New Jersey    M      Green    Fall
# 3806                     71        Missouri    M       Teal  Spring
# 3807                     39        Michigan    L      Peach  Spring
# 3808                     28      Washington    M       Pink  Winter
# 3809                     33        New York    S     Maroon  Winter
# 3810                     79       Wisconsin    L      Peach    Fall
# 3811                     30           Idaho    M     Maroon  Winter
# 3812                     75        Michigan    M       Pink  Spring
# 3813                     89         Georgia    M     Orange  Summer
# 3814                     95        Michigan    M     Orange  Winter
# 3815                     44           Maine    M      Brown    Fall
# 3816                     86        Maryland    S     Silver  Summer
# 3817                     91        Missouri    M    Magenta    Fall
# 3818                     41          Oregon   XL     Indigo  Winter
# 3819                     99        Arkansas    S       Gold  Spring
# 3820                     65   New Hampshire    M     Purple  Winter
# 3821                     48          Oregon    M       Gold  Summer
# 3822                     41          Kansas    S       Gold  Spring
# 3823                     42      California    M       Gold  Summer
# 3824                     26         Georgia    M      Olive  Summer
# 3825                     35          Hawaii    L      Green    Fall
# 3826                     31         Montana    M       Gray  Summer
# 3827                     73         Montana    M        Red  Summer
# 3828                     82     Mississippi    M   Charcoal  Spring
# 3829                     32      Washington    M     Indigo  Spring
# 3830                     27    Pennsylvania    M     Indigo  Summer
# 3831                     86          Nevada    L     Silver  Spring
# 3832                     38          Kansas   XL     Purple  Winter
# 3833                     93         Arizona    L       Gray  Summer
# 3834                     59       Tennessee    M    Magenta  Winter
# 3835                     58    Pennsylvania    L     Silver  Winter
# 3836                     84          Alaska    M     Violet  Spring
# 3837                    100      New Mexico    M      Green  Spring
# 3838                     25    Rhode Island    L      Green  Summer
# 3839                     29     Connecticut    M      Peach  Spring
# 3840                     42           Idaho    M  Turquoise  Spring
# 3841                     57     Mississippi    L       Pink    Fall
# 3842                     84        Colorado    L   Lavender  Winter
# 3843                     71         Georgia    L     Silver  Winter
# 3844                     87         Montana    S       Cyan    Fall
# 3845                     52      California    M      Green  Winter
# 3846                     58    Pennsylvania    L     Orange  Summer
# 3847                     34        Delaware    S       Blue    Fall
# 3848                     60   New Hampshire    M    Magenta  Winter
# 3849                     68         Florida    S       Cyan  Winter
# 3850                     74     Mississippi    L     Indigo  Summer
# 3851                     83         Montana    M       Pink  Summer
# 3852                     79     Mississippi    M      Peach    Fall
# 3853                     76       Tennessee    M   Lavender    Fall
# 3854                     20         Florida    M      Black  Spring
# 3855                     61        Illinois   XL   Lavender  Summer
# 3856                     78        Virginia    S      Brown  Summer
# 3857                     21           Texas    S     Yellow  Summer
# 3858                     77        Missouri    M      Olive  Winter
# 3859                     88     Mississippi    S       Blue    Fall
# 3860                     64    Pennsylvania    M  Turquoise  Summer
# 3861                     57         Wyoming    M     Yellow  Spring
# 3862                     49           Idaho    L  Turquoise  Winter
# 3863                     35   New Hampshire    M     Orange  Summer
# 3864                     99         Wyoming    S       Blue  Winter
# 3865                     42        Nebraska    M      Olive  Spring
# 3866                     32          Alaska    M      Beige  Winter
# 3867                     21        Maryland    L   Lavender  Summer
# 3868                     29        Maryland   XL    Magenta  Winter
# 3869                     64         Arizona    L       Cyan  Spring
# 3870                     46            Ohio    L   Lavender    Fall
# 3871                     97       Minnesota    M      Black    Fall
# 3872                     94   New Hampshire    M      Green  Spring
# 3873                     43       Louisiana    L     Silver  Summer
# 3874                     54          Nevada   XL      Beige  Summer
# 3875                     51   New Hampshire    M       Pink  Winter
# 3876                     85       Wisconsin    S       Cyan    Fall
# 3877                     96          Nevada    M      Olive  Spring
# 3878                     42  South Carolina    M       Pink  Summer
# 3879                     63         Florida    L     Maroon  Winter
# 3880                     20   Massachusetts    M        Red  Winter
# 3881                     25         Georgia    L     Silver  Spring
# 3882                     95    North Dakota    L       Blue    Fall
# 3883                     38    North Dakota   XL     Purple    Fall
# 3884                     29        Maryland    M      Brown    Fall
# 3885                     64      New Mexico    L     Purple  Winter
# 3886                     92            Iowa    S      Brown  Summer
# 3887                     34          Kansas    M   Charcoal  Spring
# 3888                     69        Virginia    M     Violet  Spring
# 3889                     65          Alaska    S     Yellow  Spring
# 3890                     81        Nebraska   XL      Green  Winter
# 3891                     30        Colorado    L      Peach  Winter
# 3892                     86        Michigan    L     Indigo  Summer
# 3893                     64   Massachusetts    L      White    Fall
# 3894                     78     Connecticut    L      White  Spring
# 3895                     28        Virginia    L  Turquoise  Summer
# 3896                     49            Iowa    L      White  Spring
# 3897                     33      New Jersey    L      Green  Spring
# 3898                     77       Minnesota    S      Brown  Summer
# 3899                     81      California    M      Beige  Spring
#
#       Review Rating Subscription Status   Shipping Type Discount Applied  \
# 3700           3.40                  No    Store Pickup               No
# 3701           4.50                  No    Store Pickup               No
# 3702           2.70                  No    Store Pickup               No
# 3703           2.90                  No        Standard               No
# 3704           4.00                  No    Store Pickup               No
# 3705           3.20                  No   Free Shipping               No
# 3706           4.00                  No    Store Pickup               No
# 3707           3.40                  No  2-Day Shipping               No
# 3708           4.90                  No         Express               No
# 3709           3.60                  No   Free Shipping               No
# 3710           3.60                  No  2-Day Shipping               No
# 3711           3.20                  No   Free Shipping               No
# 3712           3.70                  No  2-Day Shipping               No
# 3713           2.60                  No         Express               No
# 3714           3.90                  No         Express               No
# 3715           3.40                  No   Free Shipping               No
# 3716           3.40                  No    Next Day Air               No
# 3717           4.20                  No         Express               No
# 3718           2.90                  No        Standard               No
# 3719           4.10                  No   Free Shipping               No
# 3720           3.60                  No   Free Shipping               No
# 3721           4.00                  No    Next Day Air               No
# 3722           4.00                  No        Standard               No
# 3723           3.60                  No   Free Shipping               No
# 3724           3.10                  No         Express               No
# 3725           4.40                  No    Next Day Air               No
# 3726           4.30                  No    Next Day Air               No
# 3727           3.50                  No    Next Day Air               No
# 3728           3.00                  No        Standard               No
# 3729           4.70                  No  2-Day Shipping               No
# 3730           2.50                  No  2-Day Shipping               No
# 3731           3.10                  No  2-Day Shipping               No
# 3732           3.30                  No   Free Shipping               No
# 3733           4.70                  No    Next Day Air               No
# 3734           3.40                  No    Next Day Air               No
# 3735           3.10                  No  2-Day Shipping               No
# 3736           4.60                  No    Store Pickup               No
# 3737           4.90                  No   Free Shipping               No
# 3738           2.70                  No   Free Shipping               No
# 3739           4.20                  No   Free Shipping               No
# 3740           2.60                  No    Store Pickup               No
# 3741           3.20                  No  2-Day Shipping               No
# 3742           4.40                  No        Standard               No
# 3743           3.60                  No   Free Shipping               No
# 3744           2.70                  No    Next Day Air               No
# 3745           4.30                  No         Express               No
# 3746           2.60                  No    Next Day Air               No
# 3747           4.30                  No    Store Pickup               No
# 3748           3.90                  No  2-Day Shipping               No
# 3749           2.90                  No  2-Day Shipping               No
# 3750           3.10                  No   Free Shipping               No
# 3751           4.20                  No   Free Shipping               No
# 3752           4.10                  No  2-Day Shipping               No
# 3753           4.20                  No    Next Day Air               No
# 3754           4.40                  No         Express               No
# 3755           3.40                  No   Free Shipping               No
# 3756           4.80                  No         Express               No
# 3757           4.50                  No  2-Day Shipping               No
# 3758           2.70                  No    Store Pickup               No
# 3759           3.50                  No    Store Pickup               No
# 3760           3.10                  No    Next Day Air               No
# 3761           2.80                  No    Next Day Air               No
# 3762           2.90                  No    Store Pickup               No
# 3763           4.50                  No        Standard               No
# 3764           3.50                  No    Next Day Air               No
# 3765           4.30                  No        Standard               No
# 3766           4.90                  No    Next Day Air               No
# 3767           3.10                  No   Free Shipping               No
# 3768           4.00                  No   Free Shipping               No
# 3769           3.60                  No        Standard               No
# 3770           4.00                  No    Store Pickup               No
# 3771           2.60                  No         Express               No
# 3772           3.10                  No    Next Day Air               No
# 3773           3.50                  No    Store Pickup               No
# 3774           3.90                  No        Standard               No
# 3775           2.70                  No  2-Day Shipping               No
# 3776           4.10                  No        Standard               No
# 3777           4.30                  No         Express               No
# 3778           2.90                  No   Free Shipping               No
# 3779           4.00                  No         Express               No
# 3780           4.10                  No   Free Shipping               No
# 3781           3.70                  No        Standard               No
# 3782           2.80                  No   Free Shipping               No
# 3783           3.20                  No   Free Shipping               No
# 3784           4.50                  No    Next Day Air               No
# 3785           3.80                  No        Standard               No
# 3786           3.60                  No  2-Day Shipping               No
# 3787           3.60                  No  2-Day Shipping               No
# 3788           3.20                  No    Next Day Air               No
# 3789           3.80                  No         Express               No
# 3790           4.40                  No        Standard               No
# 3791           3.70                  No    Store Pickup               No
# 3792           2.60                  No         Express               No
# 3793           4.00                  No        Standard               No
# 3794           3.60                  No  2-Day Shipping               No
# 3795           2.50                  No         Express               No
# 3796           3.20                  No   Free Shipping               No
# 3797           2.50                  No    Next Day Air               No
# 3798           3.20                  No    Next Day Air               No
# 3799           2.60                  No    Store Pickup               No
# 3800           4.80                  No    Next Day Air               No
# 3801           5.00                  No    Store Pickup               No
# 3802           3.20                  No  2-Day Shipping               No
# 3803           3.60                  No        Standard               No
# 3804           2.70                  No  2-Day Shipping               No
# 3805           3.10                  No        Standard               No
# 3806           3.00                  No        Standard               No
# 3807           2.90                  No    Next Day Air               No
# 3808           4.70                  No         Express               No
# 3809           3.70                  No        Standard               No
# 3810           3.90                  No   Free Shipping               No
# 3811           4.00                  No        Standard               No
# 3812           2.80                  No    Next Day Air               No
# 3813           4.10                  No         Express               No
# 3814           4.20                  No   Free Shipping               No
# 3815           4.30                  No         Express               No
# 3816           4.30                  No    Store Pickup               No
# 3817           2.60                  No         Express               No
# 3818           3.80                  No   Free Shipping               No
# 3819           2.90                  No         Express               No
# 3820           5.00                  No        Standard               No
# 3821           4.60                  No   Free Shipping               No
# 3822           3.20                  No   Free Shipping               No
# 3823           3.00                  No        Standard               No
# 3824           4.00                  No   Free Shipping               No
# 3825           4.10                  No         Express               No
# 3826           4.00                  No         Express               No
# 3827           4.10                  No        Standard               No
# 3828           3.40                  No   Free Shipping               No
# 3829           2.90                  No   Free Shipping               No
# 3843              No                  48          Venmo         Every 3 Months
# 3844              No                  40          Venmo              Quarterly
# 3845              No                  46          Venmo               Annually
# 3846              No                  40         PayPal         Every 3 Months
# 3847              No                  31         PayPal            Fortnightly
# 3848              No                  39           Cash         Every 3 Months
# 3849              No                  36         PayPal            Fortnightly
# 3850              No                  25     Debit Card         Every 3 Months
# 3851              No                  24     Debit Card               Annually
# 3852              No                  19         PayPal                 Weekly
# 3853              No                  49     Debit Card              Bi-Weekly
# 3854              No                   4          Venmo               Annually
# 3855              No                  36           Cash              Quarterly
# 3856              No                   8     Debit Card              Quarterly
# 3857              No                  29    Credit Card         Every 3 Months
# 3858              No                  26    Credit Card              Quarterly
# 3859              No                  47  Bank Transfer              Bi-Weekly
# 3860              No                  44           Cash               Annually
# 3861              No                  49    Credit Card                Monthly
# 3862              No                   9          Venmo                Monthly
# 3863              No                  28           Cash            Fortnightly
# 3864              No                   1     Debit Card            Fortnightly
# 3865              No                  28           Cash         Every 3 Months
# 3866              No                  33    Credit Card            Fortnightly
# 3867              No                  28    Credit Card                Monthly
# 3868              No                   9           Cash               Annually
# 3869              No                  28  Bank Transfer               Annually
# 3870              No                  19           Cash         Every 3 Months
# 3871              No                  20  Bank Transfer         Every 3 Months
# 3872              No                   3           Cash                Monthly
# 3873              No                  22    Credit Card                 Weekly
# 3874              No                  33    Credit Card              Bi-Weekly
# 3875              No                  21    Credit Card               Annually
# 3876              No                   7           Cash               Annually
# 3877              No                  46     Debit Card                Monthly
# 3878              No                  24    Credit Card               Annually
# 3879              No                   6     Debit Card              Quarterly
# 3880              No                  40         PayPal                Monthly
# 3881              No                  17     Debit Card                 Weekly
# 3882              No                  24           Cash            Fortnightly
# 3883              No                  22           Cash            Fortnightly
# 3884              No                   3         PayPal                 Weekly
# 3885              No                  39           Cash              Quarterly
# 3886              No                  40     Debit Card              Quarterly
# 3887              No                   1    Credit Card              Quarterly
# 3888              No                  14          Venmo              Bi-Weekly
# 3889              No                  49  Bank Transfer               Annually
# 3890              No                  33     Debit Card               Annually
# 3891              No                   6  Bank Transfer              Quarterly
# 3892              No                   5         PayPal            Fortnightly
# 3893              No                  29  Bank Transfer              Bi-Weekly
# 3894              No                  44    Credit Card         Every 3 Months
# 3895              No                  32          Venmo                 Weekly
# 3896              No                  41  Bank Transfer              Bi-Weekly
# 3897              No                  24          Venmo              Quarterly
# 3898              No                  24          Venmo                 Weekly
# 3899              No                  33          Venmo              Quarterly

# %%
# let's create a copy of the data to avoid any changes to original data
data = df.copy()

# %%
# create two populations for use later
female = data[data["Gender"] == "Female"]
male = data[data["Gender"] == "Male"]

# %%
# checking for duplicate values in the data
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# - There are no duplicate values in the data.

# %%
# checking the names of the columns in the data
print(data.columns)
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases'],
#       dtype='object')

# %%
# checking column datatypes and number of non-null values
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3900 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
#  14  Promo Code Used         3900 non-null   object
#  15  Previous Purchases      3900 non-null   int64
#  16  Payment Method          3900 non-null   object
#  17  Frequency of Purchases  3900 non-null   object
# dtypes: float64(1), int64(4), object(13)
# memory usage: 548.6+ KB

# %% [markdown]
# * `Age`, `Purchase Amount (USD)`, `Previous Purchases` are of *integer* type.
#
# * `Review Rating` is of *float* type.
#
# * All other columns are *object* type.

# %% [markdown]
# ### Fixing the data types

# %% [markdown]
# * The columns that are *object* type we can change them to categories.
#
# * *Coverting objects to category reduces the data space required to store the dataframe*

# %%
data["Gender"] = data["Gender"].astype("category")
data["Item Purchased"] = data["Item Purchased"].astype("category")
data["Category"] = data["Category"].astype("category")
data["Location"] = data["Location"].astype("category")
data["Size"] = data["Size"].astype("category")
data["Color"] = data["Color"].astype("category")
data["Season"] = data["Season"].astype("category")
data["Subscription Status"] = data["Subscription Status"].astype("category")
data["Payment Method"] = data["Payment Method"].astype("category")
data["Shipping Type"] = data["Shipping Type"].astype("category")
data["Discount Applied"] = data["Discount Applied"].astype("category")
data["Promo Code Used"] = data["Promo Code Used"].astype("category")
data["Frequency of Purchases"] = data["Frequency of Purchases"].astype("category")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   category
#  3   Item Purchased          3900 non-null   category
#  4   Category                3900 non-null   category
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   category
#  7   Size                    3900 non-null   category
#  8   Color                   3900 non-null   category
#  9   Season                  3900 non-null   category
#  10  Review Rating           3900 non-null   float64
#  11  Subscription Status     3900 non-null   category
#  12  Shipping Type           3900 non-null   category
#  13  Discount Applied        3900 non-null   category
#  14  Promo Code Used         3900 non-null   category
#  15  Previous Purchases      3900 non-null   int64
#  16  Payment Method          3900 non-null   category
#  17  Frequency of Purchases  3900 non-null   category
# dtypes: category(13), float64(1), int64(4)
# memory usage: 207.8 KB

# %% [markdown]
# * We can see that the memory usage has decreased by 50%

# %% [markdown]
# ### Creating new columns for better analysis and visualization

# %% [markdown]
# * We will create a new column out of the `Age` column.
#
# * This new column will be of a categorical data type by dividing the column in generations. EX. Millenials, Baby Boomers, GenZ.
#
# * This is done taking in account the current year is 2023

# %%
conditions = [
    (data["Age"] >= 59),
    (data["Age"] >= 43) & (data["Age"] <= 58),
    (data["Age"] >= 27) & (data["Age"] <= 42),
    (data["Age"] >= 11) & (data["Age"] <= 26),
]

values = [
    "59-77 - Baby Booomers",
    "43-58 - GenX",
    "27-42 - Millenialls",
    "11-26 - GenZ",
]

# %%
# create new column age_group
data["age_group"] = np.select(conditions, values)

# %%
# change data type from object to category to save up in memory
data["age_group"] = data["age_group"].astype("category")

# %%
# check data types again
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   category
#  3   Item Purchased          3900 non-null   category
#  4   Category                3900 non-null   category
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   category
#  7   Size                    3900 non-null   category
#  8   Color                   3900 non-null   category
#  9   Season                  3900 non-null   category
#  10  Review Rating           3900 non-null   float64
#  11  Subscription Status     3900 non-null   category
#  12  Shipping Type           3900 non-null   category
#  13  Discount Applied        3900 non-null   category
#  14  Promo Code Used         3900 non-null   category
#  15  Previous Purchases      3900 non-null   int64
#  16  Payment Method          3900 non-null   category
#  17  Frequency of Purchases  3900 non-null   category
#  18  age_group               3900 non-null   category
# dtypes: category(14), float64(1), int64(4)
# memory usage: 211.8 KB

# %% [markdown]
# ### Checking for missing values in the data

# %%
data.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# age_group                 0
# dtype: int64

# %% [markdown]
# * There are no missing values in the dataset

# %%
# Let's look at the statistical summary of the data
data.describe().T
# Out:
#                         count    mean     std   min    25%     50%     75%  \
# Customer ID           3900.00 1950.50 1125.98  1.00 975.75 1950.50 2925.25
# Age                   3900.00   44.07   15.21 18.00  31.00   44.00   57.00
# Purchase Amount (USD) 3900.00   59.76   23.69 20.00  39.00   60.00   81.00
# Review Rating         3900.00    3.75    0.72  2.50   3.10    3.70    4.40
# Previous Purchases    3900.00   25.35   14.45  1.00  13.00   25.00   38.00
#
#                           max
# Customer ID           3900.00
# Age                     70.00
# Purchase Amount (USD)  100.00
# Review Rating            5.00
# Previous Purchases      50.00

# %%
female.describe().T
# Out:
#                         count    mean    std     min     25%     50%     75%  \
# Customer ID           1248.00 3276.50 360.41 2653.00 2964.75 3276.50 3588.25
# Age                   1248.00   44.01  14.95   18.00   31.00   44.00   57.00
# Purchase Amount (USD) 1248.00   60.25  23.42   20.00   40.00   60.00   81.00
# Review Rating         1248.00    3.74   0.72    2.50    3.10    3.70    4.30
# Previous Purchases    1248.00   24.60  14.58    1.00   12.00   24.00   37.00
#
#                           max
# Customer ID           3900.00
# Age                     70.00
# Purchase Amount (USD)  100.00
# Review Rating            5.00
# Previous Purchases      50.00

# %%
male.describe().T
# Out:
#                         count    mean    std   min    25%     50%     75%  \
# Customer ID           2652.00 1326.50 765.71  1.00 663.75 1326.50 1989.25
# Age                   2652.00   44.10  15.33 18.00  31.00   44.00   57.00
# Purchase Amount (USD) 2652.00   59.54  23.81 20.00  38.00   60.00   80.00
# Review Rating         2652.00    3.75   0.71  2.50   3.10    3.80    4.40
# Previous Purchases    2652.00   25.71  14.37  1.00  13.75   26.00   38.00
#
#                           max
# Customer ID           2652.00
# Age                     70.00
# Purchase Amount (USD)  100.00
# Review Rating            5.00
# Previous Purchases      50.00

# %% [markdown]
# * We are not dropping customer ID yet.  Customer ID is ordered.
# * This means that perhaps there is a relationship between client tenure and sales?  Let's find out!

# %% [markdown]
# ### Statistical Analysis

# %% [markdown]
# #### Observations of numerical columns

# %% [markdown]
# * We have 3,900 clients
#
# * In all cases our numerical columns's mean is very similar to the median value.
#
# * This means that the data follows a bell shape curve and does not possess massive outliers.
#
# * It is safely to say that we can use *the mean* as a measure of central tendency in all cases.
#
# * On average the `age` of our customers is 44 years old.
#
# * On average the `Purchase Amount (USD)` is 59.8 dollars.
#
# * The average `Review Rating` is 3.75.
#
# * On average customers have made 25 `Previous Purchases`

# %% [markdown]
# ### Let's look at the non-numeric columns

# %%
# filtering non-numeric columns
cat_columns = data.select_dtypes(exclude=np.number).columns
cat_columns
# Out:
# Index(['Gender', 'Item Purchased', 'Category', 'Location', 'Size', 'Color',
#        'Season', 'Subscription Status', 'Shipping Type', 'Discount Applied',
#        'Promo Code Used', 'Payment Method', 'Frequency of Purchases',
#        'age_group'],
#       dtype='object')

# %%
# printing the number of occurrences and %s of each categorical column
for column in cat_columns:

    # print("Frequency Numerical")
    # print(data[column].value_counts().sort_values(ascending=False))
    print("Frequency in Percentage (%)")
    print(data[column].value_counts().sort_values(ascending=False) / len(data) * 100)
    print("-" * 50)
# Out:
# Frequency in Percentage (%)
# Male     68.00
# Female   32.00
# Name: Gender, dtype: float64
# --------------------------------------------------
# Frequency in Percentage (%)
# ### Observations of non-numerical columns

# %% [markdown]
# * `Gender`: 68% of our clients are male and 32% are female
#
#
# * `Item Purchased`: The most purchased items are Jewerly, Blouse, and Pants.  And the least purchased items are Jeans, Gloves, Backpack.
#
#
# * However, none of the items are outliers and all `Item Purchased` seem to be spread very evenly across our data.
#
#
# * It does not seem to be an obvious problem with any of the `Item Purchased`.
#
#
# * Our sales in terms of product `Category` are as follows: Clothing 44.54%, Accessories 31.79%, Footwear 15.36%, Outer wear 8.31%
#
#
# * `Location`: The company has sales in all the 50 states.  The top 3 states in sales are Montana 2.46%, California 2.44%, and Idaho 2.38%.
#
#
# * The `Location` with the least sales are Rhode Island 1.62%, Kansas 1.62%, and Hawaii 1.67%.  However, the differences between the top three and top bottom `Location` is small and there is not an obvious problem with any state.
#
#
# * The most popular `Size` is M with 45%, followed by L 27%, S 17% and XL 11%
#
#
# * The most purchased `Color` is Olive with 4.54%, and the least purchased `Color` is Gold with 3.54%
#
#
# * The 4 `Seasons` are almost equally important for the sales of the company.  Each season sales are roughly 25%.  Spring 25.62% is the top season and Summer 24.49% the bottom.
#
#
# * Only 27% of our clients have a `Subscription`
#
#
# * Paypal 17.36%, Credit Card 17.21%, and Cash 17.18% are the top three `Payment Methods`.
#
#
# * Free shipping si the most popular `Shipping Type` with 17.31% the other methods are roughly 16%
#
#
# * `Discount Applied` & `Promo Code Used`: 43% of sales had discount/promo code used. Values in the two columns are exactly the same, meaning a Promo Code is the only type of discount.  We eliminate one column to avoid redundancy.
#
#
# * `Frequency of Purchases`: Every 3 Months   14.97%, Annually 14.67%, Quarterly 14.44%
#
#
#
# * `age_group`: Millenialls 30.77%, GenX 30.69%, Baby Boomers 22.13%.  Gen Z  16.41% is much lower than the group

# %% [markdown]
# ### Let's visualize the data

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# #### Numerical Columns

# %%
# filtering out non-numeric columns
num_columns = data.select_dtypes(include=["int64", "float64"]).columns
num_columns
# Out:
# Index(['Customer ID', 'Age', 'Purchase Amount (USD)', 'Review Rating',
#        'Previous Purchases'],
#       dtype='object')

# %%
# function to plot a boxplot and a histogram along the same scale.


def histogram_boxplot(data, feature, figsize=(10, 5), kde=False, bins=None):
    """
    Boxplot and histogram combined

    data: dataframe
    feature: dataframe column
    figsize: size of figure (default (12,7))
    kde: whether to the show density curve (default False)
    bins: number of bins for histogram (default None)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows=2,  # Number of rows of the subplot grid= 2
        sharex=True,  # x-axis will be shared among all subplots
        gridspec_kw={"height_ratios": (0.25, 0.75)},
        figsize=figsize,
    )  # creating the 2 subplots
    sns.boxplot(
        data=data, x=feature, ax=ax_box2, showmeans=True, color="violet"
    )  # boxplot will be created and a star will indicate the mean value of the column
    sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2, bins=bins, palette="winter"
    ) if bins else sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2
    )  # For histogram
    ax_hist2.axvline(
        data[feature].mean(), color="green", linestyle="--"
    )  # Add mean to the histogram
    ax_hist2.axvline(
        data[feature].median(), color="black", linestyle="-"
    )  # Add median to the histogram

# %%
######## To activate the function massively
# Loop
for col in num_columns:
    histogram_boxplot(data, col)

# %% [markdown]
# #### Categorical Columns

# %%
# function to create labeled barplots


def labeled_barplot(
    data,
    feature,
    perc=True,
    n=None,
):
    """
    Barplot with percentage at the top

    data: dataframe
    feature: dataframe column
    perc: whether to display percentages instead of count (default is False)
    n: displays the top n category levels (default is None, i.e., display all levels)
    """

    total = len(data[feature])  # length of the column
    count = data[feature].nunique()
    if n is None:
        plt.figure(figsize=(count + 1, 5))
    else:
        plt.figure(figsize=(n + 1, 5))

    plt.xticks(rotation=90, fontsize=15)
    ax = sns.countplot(
        data=data,
        x=feature,
        palette="Paired",
        order=data[feature].value_counts().index[:n].sort_values(ascending=False),
    )

    for p in ax.patches:
        if perc == True:
            label = "{:.1f}%".format(
                100 * p.get_height() / total
            )  # percentage of each class of the category
        else:
            label = p.get_height()  # count of each level of the category

        x = p.get_x() + p.get_width() / 2  # width of the plot
        y = p.get_height()  # height of the plot

        ax.annotate(
            label,
            (x, y),
            ha="center",
            va="center",
            size=12,
            xytext=(0, 5),
            textcoords="offset points",
        )  # annotate the percentage

    plt.show()  # show the plot

# %%
# for col in cat_columns:
# labeled_barplot(data, feature=col)

# %% [markdown]
# #### `Gender`:

# %%
labeled_barplot(data, "Gender", perc=True)

# %% [markdown]
# #### `Item Purchased`:

# %%
# bottom 5
sns.countplot(
    y="Item Purchased",
    data=female,
    palette="Paired",
    order=female["Item Purchased"].value_counts().iloc[-5:].index,
)
plt.title("Female: Bottom 5 Items Purchased", fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Female: Bottom 5 Items Purchased')

# %%
# bottom 5
sns.countplot(
    y="Item Purchased",
    data=male,
    palette="Paired",
    order=male["Item Purchased"].value_counts().iloc[-5:].index,
)
plt.title("Male: Bottom 5 Items Purchased", fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Male: Bottom 5 Items Purchased')

# %%
# top 5
sns.countplot(
    y="Item Purchased",
    data=female,
    palette="Paired",
    order=female["Item Purchased"].value_counts().iloc[:5].index,
)
plt.title("Female: Top 5 Items Purchased", fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Female: Top 5 Items Purchased')

# %%
# top 5
sns.countplot(
    y="Item Purchased",
    data=male,
    palette="Paired",
    order=male["Item Purchased"].value_counts().iloc[:5].index,
)
plt.title("Male: top 5 Items Purchased", fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Male: top 5 Items Purchased')

# %% [markdown]
# #### `Location`:

# %%
sns.countplot(
    y="Location",
    data=female,
    palette="Paired",
    order=female["Location"].value_counts().iloc[:5].index,
)
plt.title("Female: Top 5 Locations", fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Female: Top 5 Locations')

# %%
sns.countplot(
    y="Location",
    data=male,
    palette="Paired",
    order=male["Location"].value_counts().iloc[:5].index,
)
plt.title("male: Top 5 Locations", fontweight="bold")
# Out:
# Text(0.5, 1.0, 'male: Top 5 Locations')

# %%
sns.countplot(
    y="Location",
    data=data,
    palette="Paired",
    order=data["Location"].value_counts().iloc[:5].index,
)
plt.title("Top 5 Locations", fontweight="bold")
plt.xticks(fontweight="bold")
plt.yticks(fontweight="bold")
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, 'Montana'),
#   Text(0, 1, 'California'),
#   Text(0, 2, 'Idaho'),
#   Text(0, 3, 'Illinois'),
#   Text(0, 4, 'Alabama')])

# %% [markdown]
# #### `Size`:

# %%
labeled_barplot(female, "Size", perc=True)

# %%
labeled_barplot(male, "Size", perc=True)

# %% [markdown]
# #### `Color`:

# %%
sns.countplot(
    y="Color",
    data=female,
    palette="Paired",
    order=female["Color"].value_counts().iloc[:5].index,
)
plt.title("Female: Top 5 Colors", fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Female: Top 5 Colors')

# %%
sns.countplot(
    y="Color",
    data=male,
    palette="Paired",
    order=male["Color"].value_counts().iloc[:5].index,
)
plt.title("male: Top 5 Colors", fontweight="bold")
# Out:
# Text(0.5, 1.0, 'male: Top 5 Colors')

# %%
sns.countplot(
    y="Color",
    data=female,
    palette="Paired",
    order=female["Color"].value_counts().iloc[-5:].index,
)
plt.title("Female: Bottom 5 Colors", fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Female: Bottom 5 Colors')

# %%
sns.countplot(
    y="Color",
    data=male,
    palette="Paired",
    order=male["Color"].value_counts().iloc[-5:].index,
)
plt.title("male: bottom 5 Colors", fontweight="bold")
# Out:
# Text(0.5, 1.0, 'male: bottom 5 Colors')

# %% [markdown]
# #### `Season`:

# %%
labeled_barplot(female, "Season", perc=True)

# # lineplot to know frequency of items and how much time they are purchased previously.
# plt.figure(figsize=(15, 5))
# sns.lineplot(
#     data=data, y=data["Purchase Amount (USD)"].value_counts(), x="Season", ci=False
# )
# plt.xticks(rotation=90)
# plt.show()

# %%
labeled_barplot(male, "Season", perc=True)

# %% [markdown]
# #### `Subscription Status`:

# %%
labeled_barplot(female, "Subscription Status", perc=True)

# %%
labeled_barplot(male, "Subscription Status", perc=True)

# %% [markdown]
# #### `Shipping Type`:

# %%
labeled_barplot(female, "Shipping Type", perc=True)

# %%
labeled_barplot(male, "Shipping Type", perc=True)

# %% [markdown]
# #### `Discount Applied`:

# %%
labeled_barplot(female, "Discount Applied", perc=True)

# %%
labeled_barplot(male, "Discount Applied", perc=True)

# %% [markdown]
# #### `Payment Method`:

# %%
labeled_barplot(female, "Payment Method", perc=True)

# %%
labeled_barplot(male, "Payment Method", perc=True)

# %% [markdown]
# #### `Frequency of Purchases`:

# %%
labeled_barplot(female, "Frequency of Purchases", perc=True)

# %%
labeled_barplot(male, "Frequency of Purchases", perc=True)

# %% [markdown]
# #### `age_group`:

# %%
labeled_barplot(female, "age_group", perc=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age_group'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-509-f1264d95ea97> in <module>
# ----> 1 labeled_barplot(female, "age_group", perc=True)
#
# <ipython-input-481-e5f095d2c2a7> in labeled_barplot(data, feature, perc, n)
#      17     """
#      18
# ---> 19     total = len(data[feature])  # length of the column
#      20     count = data[feature].nunique()
#      21     if n is None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'age_group'

# %%
labeled_barplot(male, "age_group", perc=True)

# %% [markdown]
# ### Bivariate analysis

# %% [markdown]
# ### Let's see how the Purchase Amount behaves among our two Populations and attributes

# %%
num_columns

# %%
cat_columns

# %% [markdown]
# #### `Gender`:

# %%
# trending items between male and females
plt.figure(figsize=(15, 5))
sns.lineplot(
    data=data, y="Purchase Amount (USD)", x="Gender", hue="age_group", ci=False
)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### `Item Purchased`:

# %%
plt.figure(figsize=(25, 10))
sns.lineplot(
    data=data,
    y="Purchase Amount (USD)",
    x="Item Purchased",
    hue="Gender",
    ci=False,
)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(25, 10))
sns.lineplot(
    data=female,
    y="Purchase Amount (USD)",
    x="Item Purchased",
    hue="age_group",
    ci=False,
)
plt.xticks(rotation=90)
plt.title("Items Purchased by Females")
plt.show()

# %%
plt.figure(figsize=(25, 10))
sns.lineplot(
    data=male,
    y="Purchase Amount (USD)",
    x="Item Purchased",
    hue="age_group",
    ci=False,
)
plt.xticks(rotation=90)
plt.title("Items Purchased by Males")
plt.show()

# %% [markdown]
# #### `Location`:

# %%
plt.figure(figsize=(25, 10))
sns.lineplot(
    data=data,
    y="Purchase Amount (USD)",
    x="Location",
    hue="Gender",
    ci=False,
)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### `Size`:

# %%
plt.figure(figsize=(25, 10))
sns.lineplot(
    data=data,
    y="Purchase Amount (USD)",
    x="Size",
    hue="Gender",
    ci=False,
)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### `Color`:

# %%
plt.figure(figsize=(25, 10))
sns.lineplot(
    data=data,
    y="Purchase Amount (USD)",
    x="Color",
    hue="Gender",
    ci=False,
)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### `Season`:

# %%
plt.figure(figsize=(25, 10))
sns.lineplot(
    data=data,
    y="Purchase Amount (USD)",
    x="Season",
    hue="Gender",
    ci=False,
)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### `Subscription Status`:

# %%
plt.figure(figsize=(25, 10))
sns.lineplot(
    data=data,
    y="Purchase Amount (USD)",
    x="Subscription Status",
    hue="Gender",
    ci=False,
)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### `Shipping Type`:

# %%
plt.figure(figsize=(25, 10))
sns.lineplot(
    data=data,
    y="Purchase Amount (USD)",
    x="Shipping Type",
    hue="Gender",
    ci=False,
)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### `Discount Applied`:

# %%
plt.figure(figsize=(25, 10))
sns.lineplot(
    data=data,
    y="Purchase Amount (USD)",
    x="Discount Applied",
    hue="Gender",
    ci=False,
)

# %% [markdown]
# #### `Payment Method`:

# %%
plt.figure(figsize=(25, 10))
sns.lineplot(
    data=data,
    y="Purchase Amount (USD)",
    x="Payment Method",
    hue="Gender",
    ci=False,
)

# %% [markdown]
# #### `Frequency of Purchases`:

# %%
plt.figure(figsize=(25, 10))
sns.lineplot(
    data=data,
    y="Purchase Amount (USD)",
    x="Frequency of Purchases",
    hue="Gender",
    ci=False,
)

# %% [markdown]
# #### `age_group`:

# %%
plt.figure(figsize=(25, 10))
sns.lineplot(
    data=data,
    y="Purchase Amount (USD)",
    x="age_group",
    hue="Gender",
    ci=False,
)

# %%
# f = cat_columns

# %%
# # Showing lineplot between Purchases and all other columns in dataset
# pno = 1
# plt.figure(figsize=(20, 30))  # set the figure size (20,30)
# for i in f:  # for loop for creating lineplots between all columns
#     plt.subplot(6, 3, pno)
#     sns.lineplot(data=female, x=i, y="Purchase Amount (USD)", ci=False)
#     pno += 1

# %%
plt.figure(figsize=(15, 7))
sns.boxplot(data["Review Rating"], data["Gender"], palette="viridis")
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %%
plt.figure(figsize=(15, 7))
sns.boxplot(data["Customer ID"], data["Gender"], palette="viridis")
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %%
plt.figure(figsize=(15, 7))
sns.boxplot(
    data["Previous Purchases"],
    data["Gender"],
    palette="viridis",
)
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %%
cat_columns

# %%
# function to plot stacked bar chart


def stacked_barplot(data, predictor, target):
    """
    Print the category counts and plot a stacked bar chart

    data: dataframe
    predictor: independent variable
    target: target variable
    """
    count = data[predictor].nunique()
    sorter = data[target].value_counts().index[-1]
    tab1 = pd.crosstab(data[predictor], data[target], margins=True).sort_values(
        by=sorter, ascending=False
    )
    print(tab1)
    print("-" * 120)
    tab = pd.crosstab(data[predictor], data[target], normalize="index").sort_values(
        by=sorter, ascending=False
    )
    tab.plot(kind="bar", stacked=True, figsize=(count + 5, 6))
    plt.legend(
        loc="lower left",
        frameon=False,
    )
    plt.legend(loc="upper left", bbox_to_anchor=(1, 1))
    plt.show()

# %%
stacked_barplot(data, "Subscription Status", "Gender")

# %% [markdown]
# ### <a id='link1'>Summary of EDA</a>
#
# **Data Description:**
#
# - Data does not have null values
# - All object variables were converted to categorical for reasons of memory optimization
# - `age_group` column was created based on `Age` column
# - `Promo Code Used` column was not analyzed as it is a duplication of `Discount Applied`
# - There are no duplicate values in the data.
# - Data was separated by Gender to analyze customer trends.
#
# **Observations from Female vs Male Populations:**
#
# *
# *
#
#
#
#
#
# **Observations from Overall Data:**
#
# * We have 3,900 clients
#
#
# * In all cases our numerical columns's mean is very similar to the median value.
#
#
# * This means that the data follows a bell shape curve and does not possess massive outliers.
#
#
# * It is safely to say that we can use *the mean* as a measure of central tendency in all cases.
#
#
# * On average the `age` of our customers is 44 years old.
#
#
# * On average the `Purchase Amount (USD)` is 59.8 dollars.
#
#
# * The average `Review Rating` is 3.75.
#
#
# * On average customers have made 25 `Previous Purchases`
#
#
# * `Gender`: 68% of our clients are male and 32% are female
#
#
# * `Item Purchased`: The most purchased items are Jewerly, Blouse, and Pants.  And the least purchased items are Jeans, Gloves, Backpack.
#
#
# * However, none of the items are outliers and all `Item Purchased` seem to be spread very evenly across our data.
#
#
# * It does not seem to be an obvious problem with any of the `Item Purchased`.
#
#
# * Our sales in terms of product `Category` are as follows: Clothing 44.54%, Accessories 31.79%, Footwear 15.36%, Outer wear 8.31%
#
#
# * `Location`: The company has sales in all the 50 states.  The top 3 states in sales are Montana 2.46%, California 2.44%, and Idaho 2.38%.
#
#
# * The `Location` with the least sales are Rhode Island 1.62%, Kansas 1.62%, and Hawaii 1.67%.  However, the differences between the top three and top bottom `Location` is small and there is not an obvious problem with any state.
#
#
# * The most popular `Size` is M with 45%, followed by L 27%, S 17% and XL 11%
#
#
# * The most purchased `Color` is Olive with 4.54%, and the least purchased `Color` is Gold with 3.54%
#
#
# * The 4 `Seasons` are almost equally important for the sales of the company.  Each season sales are roughly 25%.  Spring 25.62% is the top season and Summer 24.49% the bottom.
#
#
# * Only 27% of our clients have a `Subscription`
#
#
# * Paypal 17.36%, Credit Card 17.21%, and Cash 17.18% are the top three `Payment Methods`.
#
#
# * Free shipping si the most popular `Shipping Type` with 17.31% the other methods are roughly 16%
#
#
# * `Discount Applied` & `Promo Code Used`: 43% of sales had discount/promo code used. Values in the two columns are exactly the same, meaning a Promo Code is the only type of discount.  We eliminate one column to avoid redundancy.
#
#
# * `Frequency of Purchases`: Every 3 Months   14.97%, Annually 14.67%, Quarterly 14.44%
#
#
#
# * `age_group`: Millenialls 30.77%, GenX 30.69%, Baby Boomers 22.13%.  Gen Z  16.41% is much lower than the group

# %% [markdown]
# ## Analysis

# %% [markdown]
# * Even though Millenials are the majority of overall.  Female genZ population demonstrate a larger interest in

# %% [markdown]
# ## Conclusions

# %% [markdown]
# ## Recommendations

# %% [markdown]
# * Focuss on growing market share for **Gen-Z** `age_group`
# * Promote subscriptions among the Female `Gender`. Currently there are none
# * Promote discounts among the Female `Gender`. Currently there are none
